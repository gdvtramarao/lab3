# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv(r"D:\\extracted_features_charrec_dense.csv")
df
# Out:
#               0         1          2    3          4          5          6  \
# 0     27.630783  0.000000  51.067493  0.0  26.302004   0.000000   0.000000
# 1     41.934185  0.000000  57.616398  0.0  40.345722   0.000000   0.000000
# 2     59.681458  0.000000  35.450397  0.0  51.084698   0.000000   0.000000
# 3     25.652845  0.000000  42.711246  0.0  26.391441   0.000000   0.000000
# 4     51.862490  0.000000  25.455917  0.0  48.505250   0.000000   0.000000
# ...         ...       ...        ...  ...        ...        ...        ...
# 6652   0.000000  8.917019  12.606703  0.0   0.000000  23.875010   0.000000
# 6653  12.088920  3.646342  28.106102  0.0   0.000000   0.000000   0.000000
# 6654   0.000000  0.000000  53.899130  0.0   0.000000   0.000000  12.079654
# 6655   0.000000  0.000000  37.811558  0.0   0.000000   0.000000   8.555406
# 6656   0.000000  0.000000  29.105694  0.0   0.000000   8.669491  20.568624
#
# ...

# %%
means = df.mean()
centroid1 = means.loc['6']
centroid2 = means.loc['12']
display= np.linalg.norm(centroid1 - centroid2)

print(f"Euclidean distance between the mean vectors of class A and B is {display:.2f}")
# Out:
# Euclidean distance between the mean vectors of class A and B is 18.88

# %%
import numpy as np
import matplotlib.pyplot as plt
xx = np.random.rand(16, 30)
fig, ax = plt.subplots()
m = ax.pcolor(xx)
m.set_zorder(-20)
w = ax.properties()
print("Display all Properties")
for i in w:
    print(i, ":", w[i])
fig.suptitle('matplotlib.axes.Axes.properties()', fontweight ="bold")

plt.show()
# Out:
# Display all Properties
# adjustable : box
# agg_filter : None
# alpha : None
# anchor : C
# animated : False
# aspect : auto
# autoscale_on : True
# autoscalex_on : True
# autoscaley_on : True
# axes_locator : None
# axisbelow : line
# box_aspect : None
# children : [<matplotlib.collections.PolyCollection object at 0x00000208CC6533D0>, <matplotlib.spines.Spine object at 0x00000208CCE48F90>, <matplotlib.spines.Spine object at 0x00000208C8FBF810>, <matplotlib.spines.Spine object at 0x00000208CC758B90>, <matplotlib.spines.Spine object at 0x00000208CC614950>, <matplotlib.axis.XAxis object at 0x00000208CCE5F450>, <matplotlib.axis.YAxis object at 0x00000208CC650C90>, Text(0.5, 1.0, ''), Text(0.0, 1.0, ''), Text(1.0, 1.0, ''), <matplotlib.patches.Rectangle object at 0x00000208CCE64C90>]
# clip_box : None
# clip_on : True
# clip_path : None
# data_ratio : 0.5333333333333333
# ...

# %%
import numpy as np
class_A_data = df[df['class_name'] == 3334]
class_B_data = df[df['class_name'] == 3335]
centroid_A = np.mean(class_A_data, axis=0)
centroid_B = np.mean(class_B_data, axis=0)
centroid_A
centroid_B
# Out:
# 0               33.954744
# 1                7.803311
# 2                0.929065
# 3                0.000000
# 4               48.753925
#                  ...
# 60               0.035407
# 61               5.166118
# 62              24.849326
# 63               0.000000
# class_name    3335.000000
# Length: 65, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
standev=np.std()
cent1=std.loc['12']
cent2=std.loc['11']
display=np.linalg.norm(cent1-cent2)
print("the standard deviation between vectors of class A,B is {display:.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 standev=np.std()
#       4 cent1=std.loc['12']
#       5 cent2=std.loc['11']
#
# File <__array_function__ internals>:198, in std(*args, **kwargs)
#
# TypeError: std() missing 1 required positional argument: 'a'

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(12, 22)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       4 # X is the training data and y is the corresponding labels
#       5 neigh = KNeighborsClassifier(n_neighbors=3)
# ----> 6 neigh.fit(12, 22)
#
# File C:\anaconda\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File C:\anaconda\Lib\site-packages\sklearn\neighbors\_classification.py:228, in KNeighborsClassifier.fit(self, X, y)
#     206 @_fit_context(
#     207     # KNeighborsClassifier.metric is not validated yet
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

k_range = range(1, 11)
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(np.mean(y_pred == y_test))

plt.plot(k_range, scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"D:\\extracted_features_charrec_dense.csv")
data=pd.DataFrame(df['10'])
num_bins = 10
hist, bin_edges = np.histogram(data, bins=num_bins)
mean_data = np.mean(data)
variance_data = np.var(data)
print(f"Mean: {mean_data}")
print(f"Variance: {variance_data}")
plt.hist(data, bins=num_bins, edgecolor='k')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.grid(True)
plt.show()
# Out:
# Mean: 10    0.0
# dtype: float64
# Variance: 10    0.0
# dtype: float64
# C:\anaconda\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
import numpy as np
import matplotlib.pyplot as plt
v1 = df.iloc[0, :]  
v2 = df.iloc[1, :]  
distances = []
r_values = list(range(1,20))
for r in r_values:
    distance = np.power(np.sum(np.abs(v1 - v2) ** r), 1/r)
    distances.append(distance)

plt.plot(r_values, distances, marker='s', linestyle='--')
plt.xlabel('r')
plt.ylabel('Minkowski Dist')
plt.title('Minkowski Dist vs r value is  ')
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv(r"D:\\extracted_features_charrec_dense.csv")
a = df.iloc[:, :-1]
b = df.iloc[:, -1]
a_train, a_test, b_train, b_test = train_test_split(a, b, test_size=0.3)
b_test
# Out:
# 2957    3360
# 568     3337
# 1218    3349
# 273     3334
# 4238    3367
#         ...
# 5888    3381
# 1555    3352
# 4929    3374
# 467     3337
# 554     3337
# Name: class_name, Length: 1998, dtype: int64

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(a_train, b_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
b_train_new = np.argmax(b_train, axis=0)
b_train_new
b_train_new = np.around(b_train_new)
b_train_new
# Out:
# 83
